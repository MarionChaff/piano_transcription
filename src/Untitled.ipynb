# %%
from midi2audio import FluidSynth
import matplotlib.pyplot as plt
import librosa
import numpy as np
import pandas as pd
from PyEMD import EMD
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[51], line 6
#       4 import numpy as np
#       5 import pandas as pd
# ----> 6 from PyEMD import EMD
#
# ModuleNotFoundError: No module named 'PyEMD'

# %%
#converting a midi file to wav

filepath = '/Users/yleniafedi/Desktop/testmidi.mid'
soundfont = '/Users/yleniafedi/code/piano_transcription/FluidR3_GM/FluidR3_GM.sf2'    
fs = FluidSynth(soundfont)

if os.path.isfile(filepath):
   print('The File Exists')
else: 
   print('The File does not exist')

fs.midi_to_audio(filepath, 'output2.wav')
# Out:
# FluidSynth runtime version 2.3.4
# Copyright (C) 2000-2023 Peter Hanappe and others.
# Distributed under the LGPL license.
# SoundFont(R) is a registered trademark of Creative Technology Ltd.
#
# Rendering audio to file 'output2.wav'..

# %%
import os

path = "/Users/yleniafedi/code/piano_transcription/piano_transcription/midis"
files = list(os.scandir(path))

#for file in files:
#        print(file.name)

type(files[0])
# Out:
# posix.DirEntry

# %%
#loading our wav file with librosa

miditest = 'output2.wav'
y, sr = librosa.load(miditest, duration=15)
S = np.abs(librosa.stft(y))
pd.DataFrame(S)
# Out:
#            0             1             2             3             4    \
# 0     0.013238  2.685274e-02  3.118953e-02  3.125000e-02  3.125000e-02
# 1     0.010827  1.671825e-02  1.568027e-02  1.562500e-02  1.562500e-02
# 2     0.005769  3.009978e-03  5.898801e-05  6.536240e-12  2.897640e-19
# 3     0.002259  1.806908e-03  5.718238e-05  6.419277e-12  7.240218e-20
# 4     0.001252  8.280401e-04  5.474101e-05  6.455085e-12  2.932742e-20
# ...        ...           ...           ...           ...           ...
# 1020  0.000001  6.331489e-07  4.692784e-10  6.376618e-12  2.842255e-20
# 1021  0.000001  6.228626e-07  4.992305e-10  6.761063e-12  3.096391e-20
# 1022  0.000001  6.152452e-07  3.839677e-10  7.056862e-12  6.667454e-20
# 1023  0.000001  6.105660e-07  3.371707e-10  7.243570e-12  2.032879e-20
# 1024  0.000001  6.090939e-07  4.033417e-10  7.307419e-12  0.000000e+00
#
#                5             6             7             8             9    \
# ...

# %%
#using a fourier transform from librosa - stft
fig, ax = plt.subplots()
img = librosa.display.specshow(librosa.amplitude_to_db(S,
                                                       ref=np.max),
                               y_axis='log', x_axis='time', ax=ax)
ax.set_title('Power spectrogram')
fig.colorbar(img, ax=ax, format="%+2.0f dB")
